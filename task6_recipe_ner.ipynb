# %% [markdown]
# # Определение именованных сущностей в рецептах

# %% [markdown]
# * [1] https://open.blogs.nytimes.com/2015/04/09/extracting-structured-data-from-recipes-using-conditional-random-fields
# * [2] https://open.blogs.nytimes.com/2016/04/27/structured-ingredients-data-tagging
# * [3] https://pytorch.org/tutorials/beginner/nlp/sequence_models_tutorial.html#sphx-glr-beginner-nlp-sequence-models-tutorial-py
# * [4] https://pytorch.org/tutorials/beginner/saving_loading_models.html
# * [5] https://en.wikipedia.org/wiki/Inside%E2%80%93outside%E2%80%93beginning_(tagging)
# * [6] https://en.wikipedia.org/wiki/Named-entity_recognition

# %%
# Если Вы запускаете ноутбук на colab или kaggle,
# выполните следующие строчки, чтобы подгрузить библиотеку dlnlputils:

# !git clone https://github.com/Samsung-IT-Academy/stepik-dl-nlp.git && pip install -r stepik-dl-nlp/requirements.txt
import sys; sys.path.append('./stepik-dl-nlp')
# Out:
# Cloning into 'stepik-dl-nlp'...
# remote: Enumerating objects: 296, done.
# remote: Counting objects: 100% (2/2), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 296 (delta 0), reused 0 (delta 0), pack-reused 294 (from 2)
# Receiving objects: 100% (296/296), 42.30 MiB | 8.13 MiB/s, done.
# Resolving deltas: 100% (134/134), done.
# Updating files: 100% (51/51), done.
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from -r stepik-dl-nlp/requirements.txt (line 1)) (1.6.1)
# Collecting spacy-udpipe (from -r stepik-dl-nlp/requirements.txt (line 2))
#   Downloading spacy_udpipe-1.0.0-py3-none-any.whl.metadata (5.5 kB)
# Collecting pymorphy2 (from -r stepik-dl-nlp/requirements.txt (line 3))
#   Downloading pymorphy2-0.9.1-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: torch>=1.2 in /usr/local/lib/python3.12/dist-packages (from -r stepik-dl-nlp/requirements.txt (line 4)) (2.11.0+cpu)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from -r stepik-dl-nlp/requirements.txt (line 5)) (3.10.0)
# Collecting ipymarkup (from -r stepik-dl-nlp/requirements.txt (line 6))
#   Downloading ipymarkup-0.9.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.12/dist-packages (from -r stepik-dl-nlp/requirements.txt (line 7)) (6.1.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from -r stepik-dl-nlp/requirements.txt (line 8)) (1.16.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from -r stepik-dl-nlp/requirements.txt (line 9)) (2.2.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from -r stepik-dl-nlp/requirements.txt (line 10)) (4.67.3)
# Collecting youtokentome (from -r stepik-dl-nlp/requirements.txt (line 11))
#   Downloading youtokentome-1.0.6.tar.gz (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.7/86.7 kB 4.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (from -r stepik-dl-nlp/requirements.txt (line 12)) (0.13.2)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.12/dist-packages (from -r stepik-dl-nlp/requirements.txt (line 13)) (6.17.1)
# Requirement already satisfied: ipython in /usr/local/lib/python3.12/dist-packages (from -r stepik-dl-nlp/requirements.txt (line 14)) (7.34.0)
# Collecting pyconll (from -r stepik-dl-nlp/requirements.txt (line 15))
#   Downloading pyconll-3.3.1-py3-none-any.whl.metadata (7.9 kB)
# Collecting gensim==3.8.1 (from -r stepik-dl-nlp/requirements.txt (line 16))
#   Downloading gensim-3.8.1.tar.gz (23.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.4/23.4 MB 8.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting wget (from -r stepik-dl-nlp/requirements.txt (line 17))
#   Downloading wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py) ... done
# Collecting livelossplot==0.5.3 (from -r stepik-dl-nlp/requirements.txt (line 18))
#   Downloading livelossplot-0.5.3-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.12/dist-packages (from gensim==3.8.1->-r stepik-dl-nlp/requirements.txt (line 16)) (2.0.2)
# Requirement already satisfied: six>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from gensim==3.8.1->-r stepik-dl-nlp/requirements.txt (line 16)) (1.17.0)
# Requirement already satisfied: smart_open>=1.8.1 in /usr/local/lib/python3.12/dist-packages (from gensim==3.8.1->-r stepik-dl-nlp/requirements.txt (line 16)) (7.6.1)
# Requirement already satisfied: bokeh in /usr/local/lib/python3.12/dist-packages (from livelossplot==0.5.3->-r stepik-dl-nlp/requirements.txt (line 18)) (3.8.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->-r stepik-dl-nlp/requirements.txt (line 1)) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->-r stepik-dl-nlp/requirements.txt (line 1)) (3.6.0)
# Requirement already satisfied: spacy<4.0.0,>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from spacy-udpipe->-r stepik-dl-nlp/requirements.txt (line 2)) (3.8.14)
# Collecting ufal.udpipe>=1.2.0 (from spacy-udpipe->-r stepik-dl-nlp/requirements.txt (line 2))
#   Downloading ufal_udpipe-1.4.0.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (10 kB)
# Collecting dawg-python>=0.7.1 (from pymorphy2->-r stepik-dl-nlp/requirements.txt (line 3))
#   Downloading DAWG_Python-0.7.2-py2.py3-none-any.whl.metadata (7.0 kB)
# Collecting pymorphy2-dicts-ru<3.0,>=2.4 (from pymorphy2->-r stepik-dl-nlp/requirements.txt (line 3))
#   Downloading pymorphy2_dicts_ru-2.4.417127.4579844-py2.py3-none-any.whl.metadata (2.1 kB)
# Collecting docopt>=0.6 (from pymorphy2->-r stepik-dl-nlp/requirements.txt (line 3))
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.2->-r stepik-dl-nlp/requirements.txt (line 4)) (3.29.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.2->-r stepik-dl-nlp/requirements.txt (line 4)) (4.15.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.12/dist-packages (from torch>=1.2->-r stepik-dl-nlp/requirements.txt (line 4)) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.2->-r stepik-dl-nlp/requirements.txt (line 4)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.2->-r stepik-dl-nlp/requirements.txt (line 4)) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.2->-r stepik-dl-nlp/requirements.txt (line 4)) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.2->-r stepik-dl-nlp/requirements.txt (line 4)) (2025.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r stepik-dl-nlp/requirements.txt (line 5)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r stepik-dl-nlp/requirements.txt (line 5)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r stepik-dl-nlp/requirements.txt (line 5)) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r stepik-dl-nlp/requirements.txt (line 5)) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r stepik-dl-nlp/requirements.txt (line 5)) (26.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r stepik-dl-nlp/requirements.txt (line 5)) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r stepik-dl-nlp/requirements.txt (line 5)) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r stepik-dl-nlp/requirements.txt (line 5)) (2.9.0.post0)
# Collecting intervaltree>=3 (from ipymarkup->-r stepik-dl-nlp/requirements.txt (line 6))
#   Downloading intervaltree-3.2.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->-r stepik-dl-nlp/requirements.txt (line 9)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->-r stepik-dl-nlp/requirements.txt (line 9)) (2026.2)
# Requirement already satisfied: Click>=7.0 in /usr/local/lib/python3.12/dist-packages (from youtokentome->-r stepik-dl-nlp/requirements.txt (line 11)) (8.4.1)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel->-r stepik-dl-nlp/requirements.txt (line 13)) (1.8.15)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.12/dist-packages (from ipykernel->-r stepik-dl-nlp/requirements.txt (line 13)) (7.4.9)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel->-r stepik-dl-nlp/requirements.txt (line 13)) (0.2.2)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.12/dist-packages (from ipykernel->-r stepik-dl-nlp/requirements.txt (line 13)) (1.6.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from ipykernel->-r stepik-dl-nlp/requirements.txt (line 13)) (5.9.5)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.12/dist-packages (from ipykernel->-r stepik-dl-nlp/requirements.txt (line 13)) (26.2.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel->-r stepik-dl-nlp/requirements.txt (line 13)) (6.5.1)
# Requirement already satisfied: traitlets>=5.1.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel->-r stepik-dl-nlp/requirements.txt (line 13)) (5.7.1)
# Collecting jedi>=0.16 (from ipython->-r stepik-dl-nlp/requirements.txt (line 14))
#   Downloading jedi-0.20.0-py2.py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython->-r stepik-dl-nlp/requirements.txt (line 14)) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython->-r stepik-dl-nlp/requirements.txt (line 14)) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython->-r stepik-dl-nlp/requirements.txt (line 14)) (3.0.52)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from ipython->-r stepik-dl-nlp/requirements.txt (line 14)) (2.20.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython->-r stepik-dl-nlp/requirements.txt (line 14)) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython->-r stepik-dl-nlp/requirements.txt (line 14)) (4.9.0)
# Collecting sortedcontainers (from intervaltree>=3->ipymarkup->-r stepik-dl-nlp/requirements.txt (line 6))
#   Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython->-r stepik-dl-nlp/requirements.txt (line 14)) (0.8.7)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->ipykernel->-r stepik-dl-nlp/requirements.txt (line 13)) (0.4)
# Requirement already satisfied: jupyter-core>=4.9.2 in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->ipykernel->-r stepik-dl-nlp/requirements.txt (line 13)) (5.9.1)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython->-r stepik-dl-nlp/requirements.txt (line 14)) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->-r stepik-dl-nlp/requirements.txt (line 14)) (0.7.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart_open>=1.8.1->gensim==3.8.1->-r stepik-dl-nlp/requirements.txt (line 16)) (2.2.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.12/dist-packages (from spacy<4.0.0,>=3.0.0->spacy-udpipe->-r stepik-dl-nlp/requirements.txt (line 2)) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from spacy<4.0.0,>=3.0.0->spacy-udpipe->-r stepik-dl-nlp/requirements.txt (line 2)) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.12/dist-packages (from spacy<4.0.0,>=3.0.0->spacy-udpipe->-r stepik-dl-nlp/requirements.txt (line 2)) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.12/dist-packages (from spacy<4.0.0,>=3.0.0->spacy-udpipe->-r stepik-dl-nlp/requirements.txt (line 2)) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.12/dist-packages (from spacy<4.0.0,>=3.0.0->spacy-udpipe->-r stepik-dl-nlp/requirements.txt (line 2)) (3.0.13)
# Requirement already satisfied: thinc<8.4.0,>=8.3.12 in /usr/local/lib/python3.12/dist-packages (from spacy<4.0.0,>=3.0.0->spacy-udpipe->-r stepik-dl-nlp/requirements.txt (line 2)) (8.3.13)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.12/dist-packages (from spacy<4.0.0,>=3.0.0->spacy-udpipe->-r stepik-dl-nlp/requirements.txt (line 2)) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.5.3 in /usr/local/lib/python3.12/dist-packages (from spacy<4.0.0,>=3.0.0->spacy-udpipe->-r stepik-dl-nlp/requirements.txt (line 2)) (2.5.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.12/dist-packages (from spacy<4.0.0,>=3.0.0->spacy-udpipe->-r stepik-dl-nlp/requirements.txt (line 2)) (2.0.10)
# Requirement already satisfied: weasel<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from spacy<4.0.0,>=3.0.0->spacy-udpipe->-r stepik-dl-nlp/requirements.txt (line 2)) (1.0.0)
# Requirement already satisfied: confection<2.0.0,>=1.3.2 in /usr/local/lib/python3.12/dist-packages (from spacy<4.0.0,>=3.0.0->spacy-udpipe->-r stepik-dl-nlp/requirements.txt (line 2)) (1.3.3)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from spacy<4.0.0,>=3.0.0->spacy-udpipe->-r stepik-dl-nlp/requirements.txt (line 2)) (0.25.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from spacy<4.0.0,>=3.0.0->spacy-udpipe->-r stepik-dl-nlp/requirements.txt (line 2)) (2.32.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from spacy<4.0.0,>=3.0.0->spacy-udpipe->-r stepik-dl-nlp/requirements.txt (line 2)) (2.12.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.2->-r stepik-dl-nlp/requirements.txt (line 4)) (1.3.0)
# Requirement already satisfied: narwhals>=1.13 in /usr/local/lib/python3.12/dist-packages (from bokeh->livelossplot==0.5.3->-r stepik-dl-nlp/requirements.txt (line 18)) (2.22.0)
# Requirement already satisfied: PyYAML>=3.10 in /usr/local/lib/python3.12/dist-packages (from bokeh->livelossplot==0.5.3->-r stepik-dl-nlp/requirements.txt (line 18)) (6.0.3)
# Requirement already satisfied: xyzservices>=2021.09.1 in /usr/local/lib/python3.12/dist-packages (from bokeh->livelossplot==0.5.3->-r stepik-dl-nlp/requirements.txt (line 18)) (2026.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.2->-r stepik-dl-nlp/requirements.txt (line 4)) (3.0.3)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel->-r stepik-dl-nlp/requirements.txt (line 13)) (4.10.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.0.0->spacy<4.0.0,>=3.0.0->spacy-udpipe->-r stepik-dl-nlp/requirements.txt (line 2)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.0.0->spacy<4.0.0,>=3.0.0->spacy-udpipe->-r stepik-dl-nlp/requirements.txt (line 2)) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.0.0->spacy<4.0.0,>=3.0.0->spacy-udpipe->-r stepik-dl-nlp/requirements.txt (line 2)) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->spacy<4.0.0,>=3.0.0->spacy-udpipe->-r stepik-dl-nlp/requirements.txt (line 2)) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->spacy<4.0.0,>=3.0.0->spacy-udpipe->-r stepik-dl-nlp/requirements.txt (line 2)) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->spacy<4.0.0,>=3.0.0->spacy-udpipe->-r stepik-dl-nlp/requirements.txt (line 2)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->spacy<4.0.0,>=3.0.0->spacy-udpipe->-r stepik-dl-nlp/requirements.txt (line 2)) (2026.5.20)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from thinc<8.4.0,>=8.3.12->spacy<4.0.0,>=3.0.0->spacy-udpipe->-r stepik-dl-nlp/requirements.txt (line 2)) (1.3.3)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.0.0->spacy-udpipe->-r stepik-dl-nlp/requirements.txt (line 2)) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.0.0->spacy-udpipe->-r stepik-dl-nlp/requirements.txt (line 2)) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.0.0->spacy-udpipe->-r stepik-dl-nlp/requirements.txt (line 2)) (0.0.4)
# Requirement already satisfied: cloudpathlib>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from weasel<2.0.0,>=1.0.0->spacy<4.0.0,>=3.0.0->spacy-udpipe->-r stepik-dl-nlp/requirements.txt (line 2)) (0.24.0)
# Requirement already satisfied: httpx>=0.24.0 in /usr/local/lib/python3.12/dist-packages (from weasel<2.0.0,>=1.0.0->spacy<4.0.0,>=3.0.0->spacy-udpipe->-r stepik-dl-nlp/requirements.txt (line 2)) (0.28.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy<4.0.0,>=3.0.0->spacy-udpipe->-r stepik-dl-nlp/requirements.txt (line 2)) (4.13.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy<4.0.0,>=3.0.0->spacy-udpipe->-r stepik-dl-nlp/requirements.txt (line 2)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy<4.0.0,>=3.0.0->spacy-udpipe->-r stepik-dl-nlp/requirements.txt (line 2)) (0.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.0.0->spacy-udpipe->-r stepik-dl-nlp/requirements.txt (line 2)) (4.2.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.0.0->spacy-udpipe->-r stepik-dl-nlp/requirements.txt (line 2)) (0.1.2)
# Downloading livelossplot-0.5.3-py3-none-any.whl (30 kB)
# Downloading spacy_udpipe-1.0.0-py3-none-any.whl (11 kB)
# Downloading pymorphy2-0.9.1-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.5/55.5 kB 3.6 MB/s eta 0:00:00
# Downloading ipymarkup-0.9.0-py3-none-any.whl (14 kB)
# Downloading pyconll-3.3.1-py3-none-any.whl (27 kB)
# Downloading DAWG_Python-0.7.2-py2.py3-none-any.whl (11 kB)
# Downloading intervaltree-3.2.1-py2.py3-none-any.whl (25 kB)
# Downloading jedi-0.20.0-py2.py3-none-any.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 93.5 MB/s eta 0:00:00
# Downloading pymorphy2_dicts_ru-2.4.417127.4579844-py2.py3-none-any.whl (8.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 69.1 MB/s eta 0:00:00
# Downloading ufal_udpipe-1.4.0.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (953 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.8/953.8 kB 36.6 MB/s eta 0:00:00
# Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Building wheels for collected packages: gensim, youtokentome, wget, docopt
#   Building wheel for gensim (setup.py) ... done
#   Created wheel for gensim: filename=gensim-3.8.1-cp312-cp312-linux_x86_64.whl size=23720038 sha256=229169282cac467dfb67b1ca395fd795bbd588434f8166a1355976e105ff2a9d
#   Stored in directory: /root/.cache/pip/wheels/12/70/82/9d341e4452f68a12ccdcb2d4d2f749b321ee4ba0ce84db270c
#   Building wheel for youtokentome (setup.py) ... done
#   Created wheel for youtokentome: filename=youtokentome-1.0.6-cp312-cp312-linux_x86_64.whl size=1969217 sha256=61e94f67404db8b1c17743eed80c5ed1bc076f51328240cf0456f9bb2de7003f
#   Stored in directory: /root/.cache/pip/wheels/8a/24/0a/2af832a79d8fa50dcef7e0837fcafb870d3626b6d44556f8f9
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9655 sha256=96c28138c29dc6113d411ccb47ae8bb565b927307ac05438dbe81fce8f2f0be2
#   Stored in directory: /root/.cache/pip/wheels/01/46/3b/e29ffbe4ebe614ff224bad40fc6a5773a67a163251585a13a9
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13706 sha256=94903a12fbcf41ab7f7caa1e2ce4e4e96244edfafa0fa56b7876e6824bd037cb
#   Stored in directory: /root/.cache/pip/wheels/1a/bf/a1/4cee4f7678c68c5875ca89eaccf460593539805c3906722228
# Successfully built gensim youtokentome wget docopt
# Installing collected packages: wget, ufal.udpipe, sortedcontainers, pymorphy2-dicts-ru, docopt, dawg-python, youtokentome, pymorphy2, pyconll, jedi, intervaltree, ipymarkup, gensim, livelossplot, spacy-udpipe
# Successfully installed dawg-python-0.7.2 docopt-0.6.2 gensim-3.8.1 intervaltree-3.2.1 ipymarkup-0.9.0 jedi-0.20.0 livelossplot-0.5.3 pyconll-3.3.1 pymorphy2-0.9.1 pymorphy2-dicts-ru-2.4.417127.4579844 sortedcontainers-2.4.0 spacy-udpipe-1.0.0 ufal.udpipe-1.4.0.1 wget-3.2 youtokentome-1.0.6

# %%
# Для выполнения этого задания не забудьте установить:
# !pip3 install spacy_udpipe
# !pip3 install ipymarkup
# !pip3 install livelossplot
# Out:
# Requirement already satisfied: spacy_udpipe in /usr/local/lib/python3.12/dist-packages (1.0.0)
# Requirement already satisfied: spacy<4.0.0,>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from spacy_udpipe) (3.8.14)
# Requirement already satisfied: ufal.udpipe>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from spacy_udpipe) (1.4.0.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.12/dist-packages (from spacy<4.0.0,>=3.0.0->spacy_udpipe) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from spacy<4.0.0,>=3.0.0->spacy_udpipe) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.12/dist-packages (from spacy<4.0.0,>=3.0.0->spacy_udpipe) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.12/dist-packages (from spacy<4.0.0,>=3.0.0->spacy_udpipe) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.12/dist-packages (from spacy<4.0.0,>=3.0.0->spacy_udpipe) (3.0.13)
# Requirement already satisfied: thinc<8.4.0,>=8.3.12 in /usr/local/lib/python3.12/dist-packages (from spacy<4.0.0,>=3.0.0->spacy_udpipe) (8.3.13)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.12/dist-packages (from spacy<4.0.0,>=3.0.0->spacy_udpipe) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.5.3 in /usr/local/lib/python3.12/dist-packages (from spacy<4.0.0,>=3.0.0->spacy_udpipe) (2.5.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.12/dist-packages (from spacy<4.0.0,>=3.0.0->spacy_udpipe) (2.0.10)
# Requirement already satisfied: weasel<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from spacy<4.0.0,>=3.0.0->spacy_udpipe) (1.0.0)
# Requirement already satisfied: confection<2.0.0,>=1.3.2 in /usr/local/lib/python3.12/dist-packages (from spacy<4.0.0,>=3.0.0->spacy_udpipe) (1.3.3)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from spacy<4.0.0,>=3.0.0->spacy_udpipe) (0.25.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.12/dist-packages (from spacy<4.0.0,>=3.0.0->spacy_udpipe) (4.67.3)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.12/dist-packages (from spacy<4.0.0,>=3.0.0->spacy_udpipe) (2.0.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from spacy<4.0.0,>=3.0.0->spacy_udpipe) (2.32.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from spacy<4.0.0,>=3.0.0->spacy_udpipe) (2.12.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from spacy<4.0.0,>=3.0.0->spacy_udpipe) (3.1.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from spacy<4.0.0,>=3.0.0->spacy_udpipe) (75.2.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from spacy<4.0.0,>=3.0.0->spacy_udpipe) (26.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.0.0->spacy<4.0.0,>=3.0.0->spacy_udpipe) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.0.0->spacy<4.0.0,>=3.0.0->spacy_udpipe) (2.41.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.0.0->spacy<4.0.0,>=3.0.0->spacy_udpipe) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.0.0->spacy<4.0.0,>=3.0.0->spacy_udpipe) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->spacy<4.0.0,>=3.0.0->spacy_udpipe) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->spacy<4.0.0,>=3.0.0->spacy_udpipe) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->spacy<4.0.0,>=3.0.0->spacy_udpipe) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->spacy<4.0.0,>=3.0.0->spacy_udpipe) (2026.5.20)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from thinc<8.4.0,>=8.3.12->spacy<4.0.0,>=3.0.0->spacy_udpipe) (1.3.3)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.0.0->spacy_udpipe) (8.4.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.0.0->spacy_udpipe) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.0.0->spacy_udpipe) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.0.0->spacy_udpipe) (0.0.4)
# Requirement already satisfied: cloudpathlib>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from weasel<2.0.0,>=1.0.0->spacy<4.0.0,>=3.0.0->spacy_udpipe) (0.24.0)
# Requirement already satisfied: smart-open>=5.2.1 in /usr/local/lib/python3.12/dist-packages (from weasel<2.0.0,>=1.0.0->spacy<4.0.0,>=3.0.0->spacy_udpipe) (7.6.1)
# Requirement already satisfied: httpx>=0.24.0 in /usr/local/lib/python3.12/dist-packages (from weasel<2.0.0,>=1.0.0->spacy<4.0.0,>=3.0.0->spacy_udpipe) (0.28.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->spacy<4.0.0,>=3.0.0->spacy_udpipe) (3.0.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy<4.0.0,>=3.0.0->spacy_udpipe) (4.13.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy<4.0.0,>=3.0.0->spacy_udpipe) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy<4.0.0,>=3.0.0->spacy_udpipe) (0.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.0.0->spacy_udpipe) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.0.0->spacy_udpipe) (2.20.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart-open>=5.2.1->weasel<2.0.0,>=1.0.0->spacy<4.0.0,>=3.0.0->spacy_udpipe) (2.2.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.0.0->spacy_udpipe) (0.1.2)
# Requirement already satisfied: ipymarkup in /usr/local/lib/python3.12/dist-packages (0.9.0)
# Requirement already satisfied: intervaltree>=3 in /usr/local/lib/python3.12/dist-packages (from ipymarkup) (3.2.1)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.12/dist-packages (from intervaltree>=3->ipymarkup) (2.4.0)
# Requirement already satisfied: livelossplot in /usr/local/lib/python3.12/dist-packages (0.5.3)
# Requirement already satisfied: ipython in /usr/local/lib/python3.12/dist-packages (from livelossplot) (7.34.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from livelossplot) (3.10.0)
# Requirement already satisfied: bokeh in /usr/local/lib/python3.12/dist-packages (from livelossplot) (3.8.2)
# Requirement already satisfied: Jinja2>=2.9 in /usr/local/lib/python3.12/dist-packages (from bokeh->livelossplot) (3.1.6)
# Requirement already satisfied: contourpy>=1.2 in /usr/local/lib/python3.12/dist-packages (from bokeh->livelossplot) (1.3.3)
# Requirement already satisfied: narwhals>=1.13 in /usr/local/lib/python3.12/dist-packages (from bokeh->livelossplot) (2.22.0)
# Requirement already satisfied: numpy>=1.16 in /usr/local/lib/python3.12/dist-packages (from bokeh->livelossplot) (2.0.2)
# Requirement already satisfied: packaging>=16.8 in /usr/local/lib/python3.12/dist-packages (from bokeh->livelossplot) (26.2)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.12/dist-packages (from bokeh->livelossplot) (2.2.2)
# Requirement already satisfied: pillow>=7.1.0 in /usr/local/lib/python3.12/dist-packages (from bokeh->livelossplot) (11.3.0)
# Requirement already satisfied: PyYAML>=3.10 in /usr/local/lib/python3.12/dist-packages (from bokeh->livelossplot) (6.0.3)
# Requirement already satisfied: tornado>=6.2 in /usr/local/lib/python3.12/dist-packages (from bokeh->livelossplot) (6.5.1)
# Requirement already satisfied: xyzservices>=2021.09.1 in /usr/local/lib/python3.12/dist-packages (from bokeh->livelossplot) (2026.3.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.12/dist-packages (from ipython->livelossplot) (75.2.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.12/dist-packages (from ipython->livelossplot) (0.20.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython->livelossplot) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython->livelossplot) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.12/dist-packages (from ipython->livelossplot) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython->livelossplot) (3.0.52)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from ipython->livelossplot) (2.20.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython->livelossplot) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.12/dist-packages (from ipython->livelossplot) (0.2.2)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython->livelossplot) (4.9.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->livelossplot) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->livelossplot) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->livelossplot) (1.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->livelossplot) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->livelossplot) (2.9.0.post0)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython->livelossplot) (0.8.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from Jinja2>=2.9->bokeh->livelossplot) (3.0.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.2->bokeh->livelossplot) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.2->bokeh->livelossplot) (2026.2)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython->livelossplot) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->livelossplot) (0.7.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->livelossplot) (1.17.0)

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd

# %%
# Если Вы запускаете ноутбук на colab или kaggle, добавьте в начало пути ./stepik-dl-nlp
df = pd.read_csv('./stepik-dl-nlp/datasets/nyt-ingredients-head.csv')

# %%
df[0:5]
# Out:
#    index                                              input              name  \
# 0      0  1 1/4 cups cooked and pureed fresh butternut s...  butternut squash
# 1      1  1 cup peeled and cooked fresh chestnuts (about...         chestnuts
# 2      2            1 medium-size onion, peeled and chopped             onion
# 3      3                    2 stalks celery, chopped coarse            celery
# 4      4                    1 1/2 tablespoons vegetable oil     vegetable oil
#
#     qty  range_end        unit  \
# 0  1.25        0.0         cup
# 1  1.00        0.0         cup
# 2  1.00        0.0         NaN
# 3  2.00        0.0       stalk
# 4  1.50        0.0  tablespoon
#
#                                              comment
# 0  cooked and pureed fresh, or 1 10-ounce package...
# 1  peeled and cooked fresh (about 20), or 1 cup c...
# 2                    medium-size, peeled and chopped
# 3                                     chopped coarse
# 4                                                NaN

# %% [markdown]
# ## Аннотированные (BIO) рецепты

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

torch.manual_seed(1)

# %%
# Если Вы запускаете ноутбук на colab или kaggle, добавьте в начало пути ./stepik-dl-nlp
datafile = './stepik-dl-nlp/datasets/BIO_recipe_dataset.txt'
lines    = open(datafile, encoding='utf-8').read().strip().split('\n')

# %% [markdown]
# #### словарь и тэги:

# %%
from dlnlputils.recipe_utils import form_vocabulary_and_tagset, prepare_data, show_markup, Converter, tag_statistics, plot_confusion_matrix, recipe_statistics, plot_recipe_statistics

# %%
vocabulary,labels = form_vocabulary_and_tagset(lines)

# %% [markdown]
# #### рецепты:

# %%
recipes_w_tags = prepare_data(lines)

len(recipes_w_tags)
# Out:
# 49847

# %%
test_recipe, test_tags = recipes_w_tags[0]
show_markup(test_recipe, test_tags)
# Out:
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #c8e6c9; background: #e8f5e9">1$1/4<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #66bb6a;">QTY</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffcdd2; background: #ffebee">cups<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #e57373;">UNIT</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffe0b2; background: #fff3e0">cooked and pureed fresh<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #ffb74d;">COMMENT</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">butternut squash<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #64b5f6;">NAME</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">,<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">OTHER</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffe0b2; background: #fff3e0">or 1 10-ounce package frozen<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #ffb74d;">COMMENT</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">squash<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #64b5f6;">NAME</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">,<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">OTHER</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffe0b2; background: #fff3e0">defrosted<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #ffb74d;">COMMENT</span></span></div>

# %% [markdown]
# #### перевод слов и тэгов в индексы - и обратно:

# %%
converter = Converter(vocabulary,labels)

# %%
test_recipe, test_tags = recipes_w_tags[0]


encoded_recipe = converter.words_to_index(test_recipe)
encoded_tags   = converter.tags_to_index(test_tags)

print(encoded_recipe)
print(encoded_tags)
print()


decoded_recipe = converter.indices_to_words(encoded_recipe)
decoded_tags   = converter.indices_to_tags(encoded_tags)

show_markup(decoded_recipe, decoded_tags)

# %%
training_data = recipes_w_tags[     :40000]
test_data     = recipes_w_tags[40000:]

# %% [markdown]
# ## LSTM

# %%
EMBEDDING_DIM = 32
HIDDEN_DIM    = 32
VOCAB_SIZE    = len(converter.word_to_idx)
TAGSET_SIZE   = len(converter.tag_to_idx)

# %%
class LSTMTagger(nn.Module):

    def __init__(self, embedding_dim, hidden_dim, vocab_size, tagset_size):

        super(LSTMTagger, self).__init__()

        self.hidden_dim      = hidden_dim
        self.word_embeddings = nn.Embedding(vocab_size, embedding_dim)
        self.lstm            = nn.LSTM(embedding_dim, hidden_dim)
        self.hidden2tag      = nn.Linear(hidden_dim, tagset_size)

    def forward(self, words):
        embeds      = self.word_embeddings(words)
        lstm_out, _ = self.lstm(embeds.view(len(words), 1, -1))
        tag_space   = self.hidden2tag(lstm_out.view(len(words), -1))
        tag_scores  = F.log_softmax(tag_space, dim=1)

        return tag_scores

    def predict_tags(self, words):
        with torch.no_grad():
            tags_pred = model(words).numpy()
            tags_pred = np.argmax(tags_pred, axis=1)

        return tags_pred

# %%
model         = LSTMTagger(EMBEDDING_DIM, HIDDEN_DIM, VOCAB_SIZE, TAGSET_SIZE)
loss_function = nn.NLLLoss()
optimizer     = optim.SGD(model.parameters(), lr=0.1)

# %%
from livelossplot import PlotLosses

liveplot = PlotLosses()

for epoch in range(1):
    for i, (recipe, tags) in enumerate(training_data):

        model.zero_grad()

        encoded_recipe = converter.words_to_index(recipe) # слово -> его номер в словаре
        encoded_tags   = converter.tags_to_index(tags)    # тэг   -> его номер в списке тэгов

        tag_scores     = model(encoded_recipe)

        loss = loss_function(tag_scores, encoded_tags)
        loss.backward()
        optimizer.step()


        if i % 500 == 0:
            liveplot.update({'negative log likelihood loss': loss})
            liveplot.draw()


        if i == 15000:
            break

# %%
def predict_tags(model, converter, recipe):

    encoded_recipe = converter.words_to_index(recipe)        # слово -> его номер в словаре

    encoded_tags   = model.predict_tags(encoded_recipe)      # предсказанные тэги (номера)

    decoded_tags   = converter.indices_to_tags(encoded_tags) # номер тэга -> тэг

    return decoded_tags

# %%
for i in range(0,10):

    recipe, tags = test_data[np.random.randint(0,7000)]

    tags_pred    = predict_tags(model, converter, recipe)

    print('истинные тэги:')
    show_markup(recipe, tags)

    print('предсказанные тэги:')
    show_markup(recipe, tags_pred)
    print()

# %% [markdown]
# ### Save & Load model

# %%
'''
torch.save(model.state_dict(), 'models/recipe.pt')
model = LSTMTagger(EMBEDDING_DIM, HIDDEN_DIM, VOCAB_SIZE, TAGSET_SIZE)

model.load_state_dict(torch.load('models/recipe.pt'))
model.eval()


recipe, tags = test_data[4444]

tags_pred = predict_tags(model, recipe)

print('ground truth:')
print(list(zip(recipe, tags)))
print()

print('prediction:')
print(list(zip(recipe, tags_pred)))


print('ground truth:')
show_markup(recipe, tags)

print('prediction:')
show_markup(recipe, tags_pred)
'''
print()

# %% [markdown]
# ## Проверка возможностей нейросети на тестовых данных:

# %% [markdown]
# ### Количество верно предсказанных тэгов:

# %%
total_correct, total_tags = tag_statistics(model, converter, test_data)


print('Статистика верно предсказанных тэгов:\n')

for tag in total_tags.keys():
    print('для {}:'.format(tag))
    print('  корректно:\t', total_correct[tag])
    print('      всего:\t',   total_tags[tag])
    print('% корректно:\t', 100 * (total_correct[tag] / float(total_tags[tag])))
    print()

print('----------')
print('в итоге:')
print('  корректно:\t', sum(total_correct.values()))
print('      всего:\t', sum(total_tags.values()))
print('% корректно:\t', 100 * (sum(total_correct.values()) / sum(total_tags.values())))

# %% [markdown]
# ### Матрица Ошибок (Confusion Matrix)

# %%
y_pred = []
y_true = []

for recipe, tags in test_data:
    y_pred += predict_tags(model,converter, recipe)
    y_true += tags

# %%
plot_confusion_matrix(y_true, y_pred, classes=list(total_tags.keys()), title='Матрица ошибок')

plt.show()

# %%
plot_confusion_matrix(y_true, y_pred, classes=list(total_tags.keys()), normalize=True,
                      title='Нормализованная матрица ошибок')

plt.show()

# %% [markdown]
# ### Количество верно размеченных рецептов:

# %%
correct_recipes, total_recipes = recipe_statistics(model, converter, test_data, 4)

# %%
plot_recipe_statistics(correct_recipes)
plot_recipe_statistics(correct_recipes, total_recipes)
